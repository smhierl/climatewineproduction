# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
climate_df=pd.read_csv('datasets/final_climate.csv')

# %%
climate_df.drop(columns='Unnamed: 0',inplace=True)

# %%
climate_df.head(20)
# Out:
#     year           county  annual_precip  annual_tavg  annual_tmin  \
# 0   2000           Fresno          20.72    55.708333         31.4
# 1   2000           Madera          25.89    56.516667         31.8
# 2   2000         Monterey          22.95    58.633333         35.9
# 3   2000             Napa          31.24    59.266667         38.1
# 4   2000       Sacramento          23.98    61.741667         38.8
# 5   2000      San Joaquin          17.57    61.633333         38.1
# 6   2000  San Luis Obispo          17.95    59.375000         36.4
# 7   2000    Santa Barbara          20.59    58.508333         38.3
# 8   2000           Sonoma          39.18    56.991667         38.8
# 9   2000             Yolo          22.23    61.616667         38.2
# 10  2001           Fresno          23.21    56.366667         28.4
# 11  2001           Madera          27.11    56.950000         29.0
# 12  2001         Monterey          25.65    58.758333         34.2
# ...

# %%
climate_df.shape
# Out:
# (210, 12)
